# %%
# %run AutoARIMA.ipynb
# Out:
# ...
# Loaded Data:
#
#         Date  Paracetamol  DemacolinTab  Asamo memfenamat  SanmolTab  \
# 0 2024-12-25           70            10               130         16
# 1 2024-12-26           30           100                30         12
# 2 2024-12-27           50            50                20         20
# 3 2024-12-28           10            50                20         28
# 4 2024-12-29           90           160               100         20
#
#    Decolgen  CTM  Promag  Amlodipine
# 0         4   10      30         100
# 1        12   20      30          60
# 2         4   10      80         100
# 3         8   10     100          60
# 4         4   10      20          50
#
# Processing column: Paracetamol
# ADF Statistic: -5.456359893580803
# p-value: 2.576424790390181e-06
# Data is stationary
# ARIMA(0, 0, 0) - AIC: 781.7848781529177, SSE: 109867.53246753421
# ARIMA(0, 0, 1) - AIC: 782.9048184122441, SSE: 108599.88508515038
# ...
